# %% [markdown]
# # Generate "TwoPhoton_MICE_noisy.pdf"

# %%
from pathlib import Path
from collections import namedtuple

# %%
Args = namedtuple("args", ["noisy", "clean",
                           "output1", "output2"])
args = Args(
    "http://www.hpca.ual.es/~vruiz/images/FDM/TwoPhoton_MICE_1.png",
    "http://www.hpca.ual.es/~vruiz/images/FDM/TwoPhoton_MICE.png",
    "TwoPhoton_MICE_noisy.pdf",
    "TwoPhoton_MICE_noisy.png"
)

# %%
try:
    import numpy as np
except:
    # !pip install numpy
    import numpy as np

try:
    import matplotlib
    import matplotlib.pyplot as plt
    import matplotlib.ticker as mticker
except:
    # !pip install matplotlib
    import matplotlib
    import matplotlib.pyplot as plt
    import matplotlib.ticker as mticker

try:
    from skimage import io as skimage_io
except:
    # !pip install scikit-image
    from skimage import io as skimage_io

try:
    import cv2
except:
    # !pip install cv2
    import cv2

import utils

# %%
# apt install cm-super-minimal
# apt install dvipng
plt.rcParams.update({
    "text.usetex": True,
    #"font.family": "Helvetica",
    "font.family": "Serif",
    "text.latex.preamble": r"\usepackage{amsmath} \usepackage{amsfonts}"
})

# %%
noisy = skimage_io.imread(args.noisy)
clean = skimage_io.imread(args.clean)

# %%
PCC = np.corrcoef(noisy.flatten(), clean.flatten())[0, 1]

# %%
PCC

# %%
plt.title(rf"$\mathrm{{TwoPhoton\_MICE\_noisy}}$, $\mathrm{{PCC}}={PCC:.2f}$")
plt.imshow(utils.normalize(noisy), cmap="gray")
plt.savefig(args.output1, bbox_inches='tight')

# %%
cv2.imwrite(args.output2, noisy)

# %%
plt.close()
