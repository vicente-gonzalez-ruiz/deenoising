# %% [markdown]
# # Confocal_BPAE_noisy.pdf, Confocal_BPAE_noisy_R.pdf, Confocal_BPAE_noisy_G.pdf, Confocal_BPAE_noisy_B.pdf, and Confocal_BPAE.png

# %%
from pathlib import Path
from collections import namedtuple

# %%
Args = namedtuple("args",
                  ["noisy_R", "noisy_G", "noisy_B", "clean_R", "clean_G", "clean_B",
                  "output1", "output2", "output3", "output4", "output5"])
args = Args(
    "http://www.hpca.ual.es/~vruiz/images/FDM/Confocal_BPAE_R_1.png",
    "http://www.hpca.ual.es/~vruiz/images/FDM/Confocal_BPAE_G_1.png",
    "http://www.hpca.ual.es/~vruiz/images/FDM/Confocal_BPAE_B_1.png",
    "http://www.hpca.ual.es/~vruiz/images/FDM/Confocal_BPAE_R.png",
    "http://www.hpca.ual.es/~vruiz/images/FDM/Confocal_BPAE_G.png",
    "http://www.hpca.ual.es/~vruiz/images/FDM/Confocal_BPAE_B.png",
    "Confocal_BPAE_noisy.pdf",
    "Confocal_BPAE_noisy_R.pdf",
    "Confocal_BPAE_noisy_G.pdf",
    "Confocal_BPAE_noisy_B.pdf",
    "Confocal_BPAE.png"
)

# %%
if Path(args.output1).exists():
    raise Exception(f"{args.output1} already exists ... exiting")

# %%
from my_google_auth import DriveHandler
service = DriveHandler.get_drive_service()

# %%
handler = DriveHandler.DriveHandler(service)

# %%
MY_SHARED_DRIVE_ID = '1hGHvkP46fxLCQbUlyYhAS_eVl6PollQM'  # "tmp" folder

# %%
file_id = handler.find_file_id(drive_file_name=args.output1, drive_folder_id=MY_SHARED_DRIVE_ID)
if file_id == None:
    print(f"{args.output1} does not exist in Google Drive. Creating ...")
else:
    print(f"Downloading {args.output1} from Google Drive")
    success = handler.download(file_id, local_save_path = args.output1)
    raise Exception(f"{args.output1} downloaded ... exiting")

# %%
file_id = handler.find_file_id(drive_file_name=args.output2, drive_folder_id=MY_SHARED_DRIVE_ID)
if file_id == None:
    print(f"{args.output2} does not exist in Google Drive. Creating ...")
else:
    print(f"Downloading {args.output2} from Google Drive")
    success = handler.download(file_id, local_save_path = args.output2)
    raise Exception(f"{args.output2} downloaded ... exiting")

# %%
file_id = handler.find_file_id(drive_file_name=args.output3, drive_folder_id=MY_SHARED_DRIVE_ID)
if file_id == None:
    print(f"{args.output3} does not exist in Google Drive. Creating ...")
else:
    print(f"Downloading {args.output3} from Google Drive")
    success = handler.download(file_id, local_save_path = args.output3)
    raise Exception(f"{args.output3} downloaded ... exiting")

# %%
file_id = handler.find_file_id(drive_file_name=args.output4, drive_folder_id=MY_SHARED_DRIVE_ID)
if file_id == None:
    print(f"{args.output4} does not exist in Google Drive. Creating ...")
else:
    print(f"Downloading {args.output4} from Google Drive")
    success = handler.download(file_id, local_save_path = args.output4)
    raise Exception(f"{args.output4} downloaded ... exiting")

# %%
from collections import namedtuple

try:
    import numpy as np
except:
    # !pip install numpy
    import numpy as np

try:
    import matplotlib
    import matplotlib.pyplot as plt
    import matplotlib.ticker as mticker
except:
    # !pip install matplotlib
    import matplotlib
    import matplotlib.pyplot as plt
    import matplotlib.ticker as mticker

try:
    from skimage import io as skimage_io
except:
    # !pip install scikit-image
    from skimage import io as skimage_io

try:
    import cv2
except:
    # !pip install cv2
    import cv2

import utils

# %%
# apt install cm-super-minimal
# apt install dvipng
plt.rcParams.update({
    "text.usetex": True,
    #"font.family": "Helvetica",
    "font.family": "Serif",
    "text.latex.preamble": r"\usepackage{amsmath} \usepackage{amsfonts}"
})

# %%
noisy_R = skimage_io.imread(args.noisy_R)
noisy_G = skimage_io.imread(args.noisy_G)
noisy_B = skimage_io.imread(args.noisy_B)

clean_R = skimage_io.imread(args.clean_R)
clean_G = skimage_io.imread(args.clean_G)
clean_B = skimage_io.imread(args.clean_B)

# %%
noisy = np.stack((noisy_R, noisy_G, noisy_B), axis=-1)
clean = np.stack((clean_R, clean_G, clean_B), axis=-1)

# %%
PCC = np.corrcoef(noisy.flatten(), clean.flatten())[0, 1]

# %%
PCC

# %%
PCC_R = np.corrcoef(noisy_R.flatten(), clean_R.flatten())[0, 1]

# %%
PCC_R

# %%
PCC_G = np.corrcoef(noisy_G.flatten(), clean_G.flatten())[0, 1]

# %%
PCC_G

# %%
PCC_B = np.corrcoef(noisy_B.flatten(), clean_B.flatten())[0, 1]

# %%
PCC_B

# %%
plt.title(rf"$\mathrm{{Confocal\_BPAE\_noisy}}$, $\mathrm{{PCC}}={PCC:.2f}$")
plt.imshow(utils.RGB_normalize(noisy))
plt.savefig('Confocal_BPAE_noisy.pdf', bbox_inches='tight')

# %%
uploaded_file_id = handler.upload(
    local_file_path=args.output1,
    drive_file_name=args.output1,
    drive_folder_id=MY_SHARED_DRIVE_ID
)

# %%
plt.title(rf"$\mathrm{{Confocal\_BPAE\_noisy\_R}}$, $\mathrm{{PCC}}={PCC_R:.2f}$")
plt.imshow(utils.normalize(noisy_R), cmap="gray")
plt.savefig('Confocal_BPAE_noisy_R.pdf', bbox_inches='tight')

# %%
uploaded_file_id = handler.upload(
    local_file_path=args.output2,
    drive_file_name=args.output2,
    drive_folder_id=MY_SHARED_DRIVE_ID
)

# %%
plt.title(rf"$\mathrm{{Confocal\_BPAE\_noisy\_G}}$, $\mathrm{{PCC}}={PCC_G:.2f}$")
plt.imshow(utils.normalize(noisy_G), cmap="gray")
plt.savefig('Confocal_BPAE_noisy_G.pdf', bbox_inches='tight')

# %%
uploaded_file_id = handler.upload(
    local_file_path=args.output3,
    drive_file_name=args.output3,
    drive_folder_id=MY_SHARED_DRIVE_ID
)

# %%
plt.title(rf"$\mathrm{{Confocal\_BPAE\_noisy\_B}}$, $\mathrm{{PCC}}={PCC_B:.2f}$")
plt.imshow(utils.normalize(noisy_B), cmap="gray")
plt.savefig('Confocal_BPAE_noisy_B.pdf', bbox_inches='tight')

# %%
uploaded_file_id = handler.upload(
    local_file_path=args.output4,
    drive_file_name=args.output4,
    drive_folder_id=MY_SHARED_DRIVE_ID
)

# %%
cv2.imwrite("Confocal_BPAE.png", noisy)

# %%
uploaded_file_id = handler.upload(
    local_file_path=args.output5,
    drive_file_name=args.output5,
    drive_folder_id=MY_SHARED_DRIVE_ID
)

# %%
#plt.close()
