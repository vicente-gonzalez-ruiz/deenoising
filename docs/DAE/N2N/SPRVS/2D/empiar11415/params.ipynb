# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/microscopy-processing/N2N-SPRVS/blob/main/N2N-SPRVS.ipynb)

# %% [markdown]
# # N2N-SPRVS (Noise2Noise Structure Preserving Random Voxel) tomogram denoising (empiar11415)

# %%
REO_folder="~/REO/empiar11415/"
WIN_SIZE = 15 # 15 (13 peor, 17 peor)
POLY_N = 5 # 3, 5, 7 (rinden similar)
POLY_SIGMA = 1.2 # 1.3 (peor, 1.2, peor, 1.4 peor)
STD_DEV = 4.0 # 4.0 (3.5 peor, 4.5 peor)

import numpy as np
sliice = np.s_[1250:1750, 750:1250]

# %%
print("REO_folder", REO_folder)
print("STD_DEV", STD_DEV)
print("WIN_SIZE", WIN_SIZE)
print("POLY_N", POLY_N)
print("POLY_SIGMA", POLY_SIGMA)
