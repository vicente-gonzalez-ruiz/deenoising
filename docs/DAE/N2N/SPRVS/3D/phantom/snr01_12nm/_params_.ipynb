# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/microscopy-processing/N2N-SPRVS/blob/main/N2N-SPRVS.ipynb)

# %% [markdown]
# # params (snr01_12nm)

# %%
STD_DEV = 2.0 # 2.0 - 2.5 (Cuando mayor, más denoising)
SPATIAL_SIZE = 7 # 7 (Cuanto mayor, más denoising)
SIGMA_K = 7.5 # 4.5 (Cuanto menor, más denoising)
FILTER_SIZE = 5 # 11 (Cuanto menor, más denoising, aunque 3 crea artefactos) Antes 5
import numpy as np
sliice = np.s_[:, :]

# %%
print("STD_DEV", STD_DEV)
print("SPATIAL_SIZE", SPATIAL_SIZE)
print("SIGMA_K", SIGMA_K)
print("FILTER_SIZE", FILTER_SIZE)
