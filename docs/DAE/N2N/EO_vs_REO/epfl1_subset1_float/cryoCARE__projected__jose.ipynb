# %% [markdown]
# # Projected (versión Jose)
# N2N (Noise2Noise) denoising del volumen epfl1. Utiliza 2 volúmenes $V_1$ y $V_2$, donde $V_1$ es el volumen original (que nosotros consideraremos como "even") y $V_2$ es el volumen generado a partir de proyectar cada slice $z+1$ en la dimensión Z, sobre el slice $z$ (que será el volumen ("odd").
#
# Todos los ficheros temporales se crean en `/nas/vruiz/cryoCARE/epfl1`.

# %% [markdown]
# ## Creamos $V_2$
# El volumen "odd".

# %%
# %run project_vol__jose.ipynb
# Out:
# File loaded successfully: /nas/vruiz/cryoCARE/epfl1/epfl1_subset1_float.mrc
# Data shape (Z, Y, X): (150, 768, 1024)
# Data type: float32
# Voxel size (Å): (1.00, 1.00, 1.00)
# Volume normalized to uint8 for OpenCV.
# Projecting Slices:   0%|          | 0/149 [00:00<?, ?it/s]
# Optical flow calculation and projection complete.
# Writing /nas/vruiz/cryoCARE/epfl1/projected_volume.mrc
# New MRC file '/nas/vruiz/cryoCARE/epfl1/projected_volume.mrc' was created successfully.
# Data shape: (150, 768, 1024)
# Voxel size: (0.99999976, 0.9999997, 1.)
# Data type: float32
# -rw-r----- 1 jupyter-vruiz jupyter-vruiz 471860224 oct  2 20:53 /nas/vruiz/cryoCARE/epfl1/projected_volume.mrc

# %% [markdown]
# ## Configuramos cryoCARE

# %%
# %%writefile /nas/vruiz/cryoCARE/epfl1/train_data_config__projected.json
# {
#     "even": ["epfl1_subset1_float.mrc"],
#     "odd": ["projected_volume.mrc"],
#     "mask": [""],
#     "patch_shape": [32, 32, 32],
#     "num_slices": 360,
#     "split": 0.9,
#     "tilt_axis": "Y",
#     "n_normalization_samples": 200,
#     "path": "./projected_data",
#     "overwrite": "True"
# }
# Out:
# Overwriting /nas/vruiz/cryoCARE/epfl1/train_data_config__projected.json

# %%
# %%bash
# cd /nas/vruiz/cryoCARE/epfl1
# source ~/envs/cryoCARE/bin/activate
# cryoCARE_extract_train_data.py --conf train_data_config__projected.json
# Out:
# 2025-10-02 20:53:12.974357: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# even.data.shape=(150, 768, 1024), sample_shape=[32, 32, 32]
# Computing normalization parameters:
# 100%|██████████| 200/200 [00:00<00:00, 1829.86it/s]

# %% [markdown]
# ## Entrenamos

# %%
# %%writefile /nas/vruiz/cryoCARE/epfl1/train_config__projected.json
# {
#   "train_data": "./projected_data",
#   "epochs": 150,
#   "steps_per_epoch": 200,
#   "batch_size": 16,
#   "unet_kern_size": 3,
#   "unet_n_depth": 3,
#   "unet_n_first": 16,
#   "learning_rate": 0.0004,
#   "model_name": "model",
#   "path": "./",
#   "gpu_id": [0]
# }
# Out:
# Overwriting /nas/vruiz/cryoCARE/epfl1/train_config__projected.json

# %%
# %%bash
# cd /nas/vruiz/cryoCARE/epfl1
# source ~/envs/cryoCARE/bin/activate
# cryoCARE_train.py --conf train_config__projected.json
# Out:
# 2025-10-02 20:53:18.474980: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-02 20:53:20.025952: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2025-10-02 20:53:20.026679: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2025-10-02 20:53:20.054897: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 20:53:20.056948: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:c1:00.0 name: NVIDIA A30 computeCapability: 8.0
# coreClock: 1.44GHz coreCount: 56 deviceMemorySize: 23.60GiB deviceMemoryBandwidth: 869.04GiB/s
# 2025-10-02 20:53:20.057015: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 20:53:20.057192: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:41:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.73GiB deviceMemoryBandwidth: 836.37GiB/s
# 2025-10-02 20:53:20.057210: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-02 20:53:20.061972: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2025-10-02 20:53:20.062008: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2025-10-02 20:53:20.064440: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2025-10-02 20:53:20.065850: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2025-10-02 20:53:20.069665: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2025-10-02 20:53:20.071859: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2025-10-02 20:53:20.073100: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2025-10-02 20:53:20.073181: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 20:53:20.075196: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 20:53:20.075430: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 20:53:20.077386: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 20:53:20.077555: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2025-10-02 20:53:20.097118: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2025-10-02 20:53:20.097205: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 20:53:20.099594: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:c1:00.0 name: NVIDIA A30 computeCapability: 8.0
# coreClock: 1.44GHz coreCount: 56 deviceMemorySize: 23.60GiB deviceMemoryBandwidth: 869.04GiB/s
# 2025-10-02 20:53:20.099612: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-02 20:53:20.099625: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2025-10-02 20:53:20.099635: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2025-10-02 20:53:20.099644: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2025-10-02 20:53:20.099652: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2025-10-02 20:53:20.099660: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2025-10-02 20:53:20.099669: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2025-10-02 20:53:20.099677: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2025-10-02 20:53:20.099733: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 20:53:20.111613: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 20:53:20.113500: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2025-10-02 20:53:20.113535: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-02 20:53:20.687223: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-02 20:53:20.687258: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2025-10-02 20:53:20.687265: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2025-10-02 20:53:20.687514: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 20:53:20.689141: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 20:53:20.690510: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 20:53:20.693141: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22349 MB memory) -> physical GPU (device: 0, name: NVIDIA A30, pci bus id: 0000:c1:00.0, compute capability: 8.0)
# WARNING:tensorflow:NCCL is not supported when using virtual GPUs, fallingback to reduction to one device
# 2025-10-02 20:53:20.912544: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:656] In AUTO-mode, and switching to DATA-based sharding, instead of FILE-based sharding as we cannot find appropriate reader dataset op(s) to shard. Error: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_2"
# op: "FlatMapDataset"
# input: "TensorDataset/_1"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_flat_map_fn_645"
#     }
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: 32
#         }
#         dim {
#           size: 32
#         }
#         dim {
#           size: 32
#         }
#         dim {
#           size: 1
#         }
#       }
#       shape {
#         dim {
#           size: 32
#         }
#         dim {
#           size: 32
#         }
#         dim {
#           size: 32
#         }
#         dim {
#           size: 1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_FLOAT
#       type: DT_FLOAT
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 2025-10-02 20:53:20.920997: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2025-10-02 20:53:20.921329: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2595155000 Hz
# Looking for GPU with ID: 0
# GPU 0 successfully found
# 0 1
# 1 32
# 2 32
# 3 32
# 4 1
# Epoch 1/150
# 2025-10-02 20:53:23.970681: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2025-10-02 20:53:25.739853: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2025-10-02 20:53:25.840163: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2025-10-02 20:53:27.048547: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2025-10-02 20:53:27.700409: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2025-10-02 20:53:46.729807: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-10-02 20:54:14.823261: W tensorflow/core/grappler/optimizers/data/auto_shard.cc:656] In AUTO-mode, and switching to DATA-based sharding, instead of FILE-based sharding as we cannot find appropriate reader dataset op(s) to shard. Error: Did not find a shardable source, walked to a node which is not a dataset: name: "FlatMapDataset/_2"
# op: "FlatMapDataset"
# input: "TensorDataset/_1"
# attr {
#   key: "Targuments"
#   value {
#     list {
#     }
#   }
# }
# attr {
#   key: "f"
#   value {
#     func {
#       name: "__inference_Dataset_flat_map_flat_map_fn_689"
#     }
#   }
# }
# attr {
#   key: "output_shapes"
#   value {
#     list {
#       shape {
#         dim {
#           size: 32
#         }
#         dim {
#           size: 32
#         }
#         dim {
#           size: 32
#         }
#         dim {
#           size: 1
#         }
#       }
#       shape {
#         dim {
#           size: 32
#         }
#         dim {
#           size: 32
#         }
#         dim {
#           size: 32
#         }
#         dim {
#           size: 1
#         }
#       }
#     }
#   }
# }
# attr {
#   key: "output_types"
#   value {
#     list {
#       type: DT_FLOAT
#       type: DT_FLOAT
#     }
#   }
# }
# . Consider either turning off auto-sharding or switching the auto_shard_policy to DATA to shard this dataset. You can do this by creating a new `tf.data.Options()` object then setting `options.experimental_distribute.auto_shard_policy = AutoShardPolicy.DATA` before applying the options object to the dataset via `dataset.with_options(options)`.
# 200/200 [==============================] - 76s 157ms/step - loss: 0.1585 - mse: 0.1585 - mae: 0.3140 - val_loss: 0.1133 - val_mse: 0.1133 - val_mae: 0.2667
# Epoch 2/150
# 200/200 [==============================] - 8s 41ms/step - loss: 0.1141 - mse: 0.1141 - mae: 0.2676 - val_loss: 0.1101 - val_mse: 0.1101 - val_mae: 0.2629
# Epoch 3/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1111 - mse: 0.1111 - mae: 0.2641 - val_loss: 0.1095 - val_mse: 0.1095 - val_mae: 0.2622
# Epoch 4/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1100 - mse: 0.1100 - mae: 0.2628 - val_loss: 0.1081 - val_mse: 0.1081 - val_mae: 0.2607
# Epoch 5/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1097 - mse: 0.1097 - mae: 0.2624 - val_loss: 0.1074 - val_mse: 0.1074 - val_mae: 0.2598
# Epoch 6/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1092 - mse: 0.1092 - mae: 0.2619 - val_loss: 0.1056 - val_mse: 0.1056 - val_mae: 0.2576
# Epoch 7/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1090 - mse: 0.1090 - mae: 0.2616 - val_loss: 0.1069 - val_mse: 0.1069 - val_mae: 0.2592
# Epoch 8/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1090 - mse: 0.1090 - mae: 0.2616 - val_loss: 0.1067 - val_mse: 0.1067 - val_mae: 0.2588
# Epoch 9/150
# 200/200 [==============================] - 8s 41ms/step - loss: 0.1088 - mse: 0.1088 - mae: 0.2613 - val_loss: 0.1083 - val_mse: 0.1083 - val_mae: 0.2608
# Epoch 10/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1087 - mse: 0.1087 - mae: 0.2612 - val_loss: 0.1059 - val_mse: 0.1059 - val_mae: 0.2579
# Epoch 11/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1089 - mse: 0.1089 - mae: 0.2615 - val_loss: 0.1072 - val_mse: 0.1072 - val_mae: 0.2595
# Epoch 12/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1085 - mse: 0.1085 - mae: 0.2610 - val_loss: 0.1072 - val_mse: 0.1072 - val_mae: 0.2595
# Epoch 13/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1085 - mse: 0.1085 - mae: 0.2610 - val_loss: 0.1069 - val_mse: 0.1069 - val_mae: 0.2592
# Epoch 14/150
# 200/200 [==============================] - 8s 41ms/step - loss: 0.1085 - mse: 0.1085 - mae: 0.2609 - val_loss: 0.1065 - val_mse: 0.1065 - val_mae: 0.2586
# Epoch 15/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1083 - mse: 0.1083 - mae: 0.2608 - val_loss: 0.1067 - val_mse: 0.1067 - val_mae: 0.2588
# Epoch 16/150
# 200/200 [==============================] - 8s 41ms/step - loss: 0.1084 - mse: 0.1084 - mae: 0.2609 - val_loss: 0.1063 - val_mse: 0.1063 - val_mae: 0.2583
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00019999999494757503.
# Epoch 17/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1082 - mse: 0.1082 - mae: 0.2607 - val_loss: 0.1060 - val_mse: 0.1060 - val_mae: 0.2583
# Epoch 18/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1082 - mse: 0.1082 - mae: 0.2607 - val_loss: 0.1066 - val_mse: 0.1066 - val_mae: 0.2588
# Epoch 19/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1079 - mse: 0.1079 - mae: 0.2603 - val_loss: 0.1065 - val_mse: 0.1065 - val_mae: 0.2587
# Epoch 20/150
# 200/200 [==============================] - 8s 39ms/step - loss: 0.1082 - mse: 0.1082 - mae: 0.2606 - val_loss: 0.1060 - val_mse: 0.1060 - val_mae: 0.2581
# Epoch 21/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1082 - mse: 0.1082 - mae: 0.2606 - val_loss: 0.1062 - val_mse: 0.1062 - val_mae: 0.2582
# Epoch 22/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1082 - mse: 0.1082 - mae: 0.2606 - val_loss: 0.1067 - val_mse: 0.1067 - val_mae: 0.2588
# Epoch 23/150
# 200/200 [==============================] - 8s 39ms/step - loss: 0.1081 - mse: 0.1081 - mae: 0.2605 - val_loss: 0.1065 - val_mse: 0.1065 - val_mae: 0.2587
# Epoch 24/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1079 - mse: 0.1079 - mae: 0.2603 - val_loss: 0.1055 - val_mse: 0.1055 - val_mae: 0.2571
# Epoch 25/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1075 - mse: 0.1075 - mae: 0.2599 - val_loss: 0.1062 - val_mse: 0.1062 - val_mae: 0.2582
# Epoch 26/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1069 - mse: 0.1069 - mae: 0.2592 - val_loss: 0.1070 - val_mse: 0.1070 - val_mae: 0.2590
# Epoch 27/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1055 - mse: 0.1055 - mae: 0.2576 - val_loss: 0.1070 - val_mse: 0.1070 - val_mae: 0.2591
# Epoch 28/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1038 - mse: 0.1038 - mae: 0.2555 - val_loss: 0.1094 - val_mse: 0.1094 - val_mae: 0.2615
# Epoch 29/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.1010 - mse: 0.1010 - mae: 0.2519 - val_loss: 0.1123 - val_mse: 0.1123 - val_mae: 0.2644
# Epoch 30/150
# 200/200 [==============================] - 8s 41ms/step - loss: 0.0949 - mse: 0.0949 - mae: 0.2428 - val_loss: 0.1158 - val_mse: 0.1158 - val_mae: 0.2668
# Epoch 31/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0897 - mse: 0.0897 - mae: 0.2339 - val_loss: 0.1173 - val_mse: 0.1173 - val_mae: 0.2686
# Epoch 32/150
# 200/200 [==============================] - 8s 41ms/step - loss: 0.0878 - mse: 0.0878 - mae: 0.2308 - val_loss: 0.1156 - val_mse: 0.1156 - val_mae: 0.2663
# Epoch 33/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0870 - mse: 0.0870 - mae: 0.2296 - val_loss: 0.1098 - val_mse: 0.1098 - val_mae: 0.2597
# Epoch 34/150
# 200/200 [==============================] - 8s 41ms/step - loss: 0.0864 - mse: 0.0864 - mae: 0.2287 - val_loss: 0.1070 - val_mse: 0.1070 - val_mae: 0.2558
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 35/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0862 - mse: 0.0862 - mae: 0.2283 - val_loss: 0.1130 - val_mse: 0.1130 - val_mae: 0.2632
# Epoch 36/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0858 - mse: 0.0858 - mae: 0.2277 - val_loss: 0.1136 - val_mse: 0.1136 - val_mae: 0.2637
# Epoch 37/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0856 - mse: 0.0856 - mae: 0.2274 - val_loss: 0.1108 - val_mse: 0.1108 - val_mae: 0.2605
# Epoch 38/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0851 - mse: 0.0851 - mae: 0.2265 - val_loss: 0.1146 - val_mse: 0.1146 - val_mae: 0.2652
# Epoch 39/150
# 200/200 [==============================] - 8s 41ms/step - loss: 0.0851 - mse: 0.0851 - mae: 0.2266 - val_loss: 0.1162 - val_mse: 0.1162 - val_mae: 0.2671
# Epoch 40/150
# 200/200 [==============================] - 8s 41ms/step - loss: 0.0849 - mse: 0.0849 - mae: 0.2262 - val_loss: 0.1180 - val_mse: 0.1180 - val_mae: 0.2697
# Epoch 41/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0845 - mse: 0.0845 - mae: 0.2255 - val_loss: 0.1132 - val_mse: 0.1132 - val_mae: 0.2638
# Epoch 42/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0840 - mse: 0.0840 - mae: 0.2247 - val_loss: 0.1121 - val_mse: 0.1121 - val_mae: 0.2625
# Epoch 43/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0837 - mse: 0.0837 - mae: 0.2240 - val_loss: 0.1187 - val_mse: 0.1187 - val_mae: 0.2706
# Epoch 44/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0833 - mse: 0.0833 - mae: 0.2233 - val_loss: 0.1130 - val_mse: 0.1130 - val_mae: 0.2633
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 45/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0830 - mse: 0.0830 - mae: 0.2228 - val_loss: 0.1136 - val_mse: 0.1136 - val_mae: 0.2643
# Epoch 46/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0826 - mse: 0.0826 - mae: 0.2221 - val_loss: 0.1154 - val_mse: 0.1154 - val_mae: 0.2664
# Epoch 47/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0825 - mse: 0.0825 - mae: 0.2218 - val_loss: 0.1186 - val_mse: 0.1186 - val_mae: 0.2699
# Epoch 48/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0824 - mse: 0.0824 - mae: 0.2216 - val_loss: 0.1172 - val_mse: 0.1172 - val_mae: 0.2689
# Epoch 49/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0821 - mse: 0.0821 - mae: 0.2211 - val_loss: 0.1127 - val_mse: 0.1127 - val_mae: 0.2633
# Epoch 50/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0818 - mse: 0.0818 - mae: 0.2205 - val_loss: 0.1172 - val_mse: 0.1172 - val_mae: 0.2687
# Epoch 51/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0816 - mse: 0.0816 - mae: 0.2201 - val_loss: 0.1190 - val_mse: 0.1190 - val_mae: 0.2707
# Epoch 52/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0815 - mse: 0.0815 - mae: 0.2197 - val_loss: 0.1157 - val_mse: 0.1157 - val_mae: 0.2667
# Epoch 53/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0812 - mse: 0.0812 - mae: 0.2192 - val_loss: 0.1164 - val_mse: 0.1164 - val_mae: 0.2681
# Epoch 54/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0812 - mse: 0.0812 - mae: 0.2189 - val_loss: 0.1234 - val_mse: 0.1234 - val_mae: 0.2761
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 55/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0808 - mse: 0.0808 - mae: 0.2184 - val_loss: 0.1180 - val_mse: 0.1180 - val_mae: 0.2695
# Epoch 56/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0807 - mse: 0.0807 - mae: 0.2182 - val_loss: 0.1192 - val_mse: 0.1192 - val_mae: 0.2710
# Epoch 57/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0806 - mse: 0.0806 - mae: 0.2179 - val_loss: 0.1156 - val_mse: 0.1156 - val_mae: 0.2670
# Epoch 58/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0806 - mse: 0.0806 - mae: 0.2179 - val_loss: 0.1215 - val_mse: 0.1215 - val_mae: 0.2732
# Epoch 59/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0804 - mse: 0.0804 - mae: 0.2175 - val_loss: 0.1228 - val_mse: 0.1228 - val_mae: 0.2748
# Epoch 60/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0804 - mse: 0.0804 - mae: 0.2175 - val_loss: 0.1196 - val_mse: 0.1196 - val_mae: 0.2717
# Epoch 61/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0802 - mse: 0.0802 - mae: 0.2171 - val_loss: 0.1207 - val_mse: 0.1207 - val_mae: 0.2721
# Epoch 62/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0800 - mse: 0.0800 - mae: 0.2168 - val_loss: 0.1183 - val_mse: 0.1183 - val_mae: 0.2694
# Epoch 63/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0801 - mse: 0.0801 - mae: 0.2168 - val_loss: 0.1200 - val_mse: 0.1200 - val_mae: 0.2716
# Epoch 64/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0800 - mse: 0.0800 - mae: 0.2165 - val_loss: 0.1164 - val_mse: 0.1164 - val_mae: 0.2677
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 65/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0797 - mse: 0.0797 - mae: 0.2160 - val_loss: 0.1183 - val_mse: 0.1183 - val_mae: 0.2699
# Epoch 66/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0796 - mse: 0.0796 - mae: 0.2159 - val_loss: 0.1201 - val_mse: 0.1201 - val_mae: 0.2716
# Epoch 67/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0795 - mse: 0.0795 - mae: 0.2157 - val_loss: 0.1196 - val_mse: 0.1196 - val_mae: 0.2710
# Epoch 68/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0796 - mse: 0.0796 - mae: 0.2159 - val_loss: 0.1225 - val_mse: 0.1225 - val_mae: 0.2743
# Epoch 69/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0795 - mse: 0.0795 - mae: 0.2156 - val_loss: 0.1260 - val_mse: 0.1260 - val_mae: 0.2782
# Epoch 70/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0794 - mse: 0.0794 - mae: 0.2153 - val_loss: 0.1221 - val_mse: 0.1221 - val_mae: 0.2737
# Epoch 71/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0796 - mse: 0.0796 - mae: 0.2157 - val_loss: 0.1209 - val_mse: 0.1209 - val_mae: 0.2720
# Epoch 72/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0793 - mse: 0.0793 - mae: 0.2152 - val_loss: 0.1257 - val_mse: 0.1257 - val_mae: 0.2783
# Epoch 73/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0793 - mse: 0.0793 - mae: 0.2152 - val_loss: 0.1154 - val_mse: 0.1154 - val_mae: 0.2659
# Epoch 74/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0792 - mse: 0.0792 - mae: 0.2149 - val_loss: 0.1178 - val_mse: 0.1178 - val_mae: 0.2684
#
# Epoch 00074: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 75/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0792 - mse: 0.0792 - mae: 0.2148 - val_loss: 0.1216 - val_mse: 0.1216 - val_mae: 0.2740
# Epoch 76/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0792 - mse: 0.0792 - mae: 0.2150 - val_loss: 0.1222 - val_mse: 0.1222 - val_mae: 0.2745
# Epoch 77/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0791 - mse: 0.0791 - mae: 0.2146 - val_loss: 0.1297 - val_mse: 0.1297 - val_mae: 0.2827
# Epoch 78/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0791 - mse: 0.0791 - mae: 0.2146 - val_loss: 0.1158 - val_mse: 0.1158 - val_mae: 0.2662
# Epoch 79/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0789 - mse: 0.0789 - mae: 0.2144 - val_loss: 0.1218 - val_mse: 0.1218 - val_mae: 0.2739
# Epoch 80/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0790 - mse: 0.0790 - mae: 0.2144 - val_loss: 0.1236 - val_mse: 0.1236 - val_mae: 0.2755
# Epoch 81/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0789 - mse: 0.0789 - mae: 0.2145 - val_loss: 0.1207 - val_mse: 0.1207 - val_mae: 0.2724
# Epoch 82/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0789 - mse: 0.0789 - mae: 0.2143 - val_loss: 0.1194 - val_mse: 0.1194 - val_mae: 0.2704
# Epoch 83/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0789 - mse: 0.0789 - mae: 0.2143 - val_loss: 0.1245 - val_mse: 0.1245 - val_mae: 0.2765
# Epoch 84/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0788 - mse: 0.0788 - mae: 0.2141 - val_loss: 0.1225 - val_mse: 0.1225 - val_mae: 0.2739
#
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 85/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0787 - mse: 0.0787 - mae: 0.2140 - val_loss: 0.1230 - val_mse: 0.1230 - val_mae: 0.2746
# Epoch 86/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0786 - mse: 0.0786 - mae: 0.2139 - val_loss: 0.1233 - val_mse: 0.1233 - val_mae: 0.2748
# Epoch 87/150
# 200/200 [==============================] - 8s 41ms/step - loss: 0.0788 - mse: 0.0788 - mae: 0.2141 - val_loss: 0.1206 - val_mse: 0.1206 - val_mae: 0.2720
# Epoch 88/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0788 - mse: 0.0788 - mae: 0.2140 - val_loss: 0.1194 - val_mse: 0.1194 - val_mae: 0.2707
# Epoch 89/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0788 - mse: 0.0788 - mae: 0.2141 - val_loss: 0.1230 - val_mse: 0.1230 - val_mae: 0.2752
# Epoch 90/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0787 - mse: 0.0787 - mae: 0.2140 - val_loss: 0.1220 - val_mse: 0.1220 - val_mae: 0.2738
# Epoch 91/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0787 - mse: 0.0787 - mae: 0.2139 - val_loss: 0.1243 - val_mse: 0.1243 - val_mae: 0.2766
# Epoch 92/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0786 - mse: 0.0786 - mae: 0.2138 - val_loss: 0.1275 - val_mse: 0.1275 - val_mae: 0.2803
# Epoch 93/150
# 200/200 [==============================] - 8s 41ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2135 - val_loss: 0.1168 - val_mse: 0.1168 - val_mae: 0.2672
# Epoch 94/150
# 200/200 [==============================] - 8s 41ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2137 - val_loss: 0.1188 - val_mse: 0.1188 - val_mae: 0.2697
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 95/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2133 - val_loss: 0.1274 - val_mse: 0.1274 - val_mae: 0.2801
# Epoch 96/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0786 - mse: 0.0786 - mae: 0.2136 - val_loss: 0.1292 - val_mse: 0.1292 - val_mae: 0.2819
# Epoch 97/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2137 - val_loss: 0.1177 - val_mse: 0.1177 - val_mae: 0.2691
# Epoch 98/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0787 - mse: 0.0787 - mae: 0.2138 - val_loss: 0.1175 - val_mse: 0.1175 - val_mae: 0.2681
# Epoch 99/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0786 - mse: 0.0786 - mae: 0.2137 - val_loss: 0.1287 - val_mse: 0.1287 - val_mae: 0.2821
# Epoch 100/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0787 - mse: 0.0787 - mae: 0.2137 - val_loss: 0.1204 - val_mse: 0.1204 - val_mae: 0.2717
# Epoch 101/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2136 - val_loss: 0.1203 - val_mse: 0.1203 - val_mae: 0.2712
# Epoch 102/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0786 - mse: 0.0786 - mae: 0.2138 - val_loss: 0.1266 - val_mse: 0.1266 - val_mae: 0.2793
# Epoch 103/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2133 - val_loss: 0.1255 - val_mse: 0.1255 - val_mae: 0.2776
# Epoch 104/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2135 - val_loss: 0.1246 - val_mse: 0.1246 - val_mae: 0.2766
#
# Epoch 00104: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 105/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2135 - val_loss: 0.1217 - val_mse: 0.1217 - val_mae: 0.2731
# Epoch 106/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2135 - val_loss: 0.1230 - val_mse: 0.1230 - val_mae: 0.2744
# Epoch 107/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0783 - mse: 0.0783 - mae: 0.2132 - val_loss: 0.1248 - val_mse: 0.1248 - val_mae: 0.2774
# Epoch 108/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2134 - val_loss: 0.1235 - val_mse: 0.1235 - val_mae: 0.2754
# Epoch 109/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0786 - mse: 0.0786 - mae: 0.2138 - val_loss: 0.1204 - val_mse: 0.1204 - val_mae: 0.2716
# Epoch 110/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0787 - mse: 0.0787 - mae: 0.2138 - val_loss: 0.1250 - val_mse: 0.1250 - val_mae: 0.2777
# Epoch 111/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2134 - val_loss: 0.1232 - val_mse: 0.1232 - val_mae: 0.2754
# Epoch 112/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0786 - mse: 0.0786 - mae: 0.2136 - val_loss: 0.1262 - val_mse: 0.1262 - val_mae: 0.2789
# Epoch 113/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2135 - val_loss: 0.1221 - val_mse: 0.1221 - val_mae: 0.2735
# Epoch 114/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2134 - val_loss: 0.1236 - val_mse: 0.1236 - val_mae: 0.2754
#
# Epoch 00114: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Epoch 115/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2134 - val_loss: 0.1246 - val_mse: 0.1246 - val_mae: 0.2764
# Epoch 116/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0782 - mse: 0.0782 - mae: 0.2130 - val_loss: 0.1206 - val_mse: 0.1206 - val_mae: 0.2716
# Epoch 117/150
# 200/200 [==============================] - 8s 39ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2134 - val_loss: 0.1246 - val_mse: 0.1246 - val_mae: 0.2768
# Epoch 118/150
# 200/200 [==============================] - 8s 39ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2133 - val_loss: 0.1244 - val_mse: 0.1244 - val_mae: 0.2761
# Epoch 119/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0783 - mse: 0.0783 - mae: 0.2131 - val_loss: 0.1249 - val_mse: 0.1249 - val_mae: 0.2768
# Epoch 120/150
# 200/200 [==============================] - 8s 39ms/step - loss: 0.0783 - mse: 0.0783 - mae: 0.2131 - val_loss: 0.1224 - val_mse: 0.1224 - val_mae: 0.2745
# Epoch 121/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0786 - mse: 0.0786 - mae: 0.2136 - val_loss: 0.1208 - val_mse: 0.1208 - val_mae: 0.2719
# Epoch 122/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0783 - mse: 0.0783 - mae: 0.2132 - val_loss: 0.1201 - val_mse: 0.1201 - val_mae: 0.2710
# Epoch 123/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2135 - val_loss: 0.1234 - val_mse: 0.1234 - val_mae: 0.2753
# Epoch 124/150
# 200/200 [==============================] - 8s 41ms/step - loss: 0.0786 - mse: 0.0786 - mae: 0.2135 - val_loss: 0.1223 - val_mse: 0.1223 - val_mae: 0.2740
#
# Epoch 00124: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# Epoch 125/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0783 - mse: 0.0783 - mae: 0.2131 - val_loss: 0.1233 - val_mse: 0.1233 - val_mae: 0.2751
# Epoch 126/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0783 - mse: 0.0783 - mae: 0.2132 - val_loss: 0.1165 - val_mse: 0.1165 - val_mae: 0.2665
# Epoch 127/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2133 - val_loss: 0.1234 - val_mse: 0.1234 - val_mae: 0.2754
# Epoch 128/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2134 - val_loss: 0.1252 - val_mse: 0.1252 - val_mae: 0.2773
# Epoch 129/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2134 - val_loss: 0.1206 - val_mse: 0.1206 - val_mae: 0.2717
# Epoch 130/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2133 - val_loss: 0.1198 - val_mse: 0.1198 - val_mae: 0.2705
# Epoch 131/150
# 200/200 [==============================] - 8s 41ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2133 - val_loss: 0.1223 - val_mse: 0.1223 - val_mae: 0.2738
# Epoch 132/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2134 - val_loss: 0.1226 - val_mse: 0.1226 - val_mae: 0.2744
# Epoch 133/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2133 - val_loss: 0.1191 - val_mse: 0.1191 - val_mae: 0.2698
# Epoch 134/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0783 - mse: 0.0783 - mae: 0.2130 - val_loss: 0.1205 - val_mse: 0.1205 - val_mae: 0.2716
#
# Epoch 00134: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# Epoch 135/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2131 - val_loss: 0.1227 - val_mse: 0.1227 - val_mae: 0.2743
# Epoch 136/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2133 - val_loss: 0.1151 - val_mse: 0.1151 - val_mae: 0.2647
# Epoch 137/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2133 - val_loss: 0.1233 - val_mse: 0.1233 - val_mae: 0.2754
# Epoch 138/150
# 200/200 [==============================] - 8s 41ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2133 - val_loss: 0.1209 - val_mse: 0.1209 - val_mae: 0.2724
# Epoch 139/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2134 - val_loss: 0.1220 - val_mse: 0.1220 - val_mae: 0.2736
# Epoch 140/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2134 - val_loss: 0.1285 - val_mse: 0.1285 - val_mae: 0.2810
# Epoch 141/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2135 - val_loss: 0.1172 - val_mse: 0.1172 - val_mae: 0.2676
# Epoch 142/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2133 - val_loss: 0.1230 - val_mse: 0.1230 - val_mae: 0.2751
# Epoch 143/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2135 - val_loss: 0.1192 - val_mse: 0.1192 - val_mae: 0.2705
# Epoch 144/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2133 - val_loss: 0.1187 - val_mse: 0.1187 - val_mae: 0.2701
#
# Epoch 00144: ReduceLROnPlateau reducing learning rate to 4.882812376649781e-08.
# Epoch 145/150
# 200/200 [==============================] - 8s 41ms/step - loss: 0.0785 - mse: 0.0785 - mae: 0.2134 - val_loss: 0.1236 - val_mse: 0.1236 - val_mae: 0.2759
# Epoch 146/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2133 - val_loss: 0.1251 - val_mse: 0.1251 - val_mae: 0.2766
# Epoch 147/150
# 200/200 [==============================] - 8s 41ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2132 - val_loss: 0.1214 - val_mse: 0.1214 - val_mae: 0.2728
# Epoch 148/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2133 - val_loss: 0.1243 - val_mse: 0.1243 - val_mae: 0.2765
# Epoch 149/150
# 200/200 [==============================] - 8s 40ms/step - loss: 0.0784 - mse: 0.0784 - mae: 0.2132 - val_loss: 0.1236 - val_mse: 0.1236 - val_mae: 0.2751
# Epoch 150/150
# 200/200 [==============================] - 8s 39ms/step - loss: 0.0783 - mse: 0.0783 - mae: 0.2131 - val_loss: 0.1186 - val_mse: 0.1186 - val_mae: 0.2690
# /home/jupyter-vruiz/envs/cryoCARE/lib/python3.8/site-packages/csbdeep/models/base_model.py:149: UserWarning: output path for model already exists, files may be overwritten: /nas/vruiz/cryoCARE/epfl1/model
#   warnings.warn('output path for model already exists, files may be overwritten: %s' % str(self.logdir.resolve()))
# Loading network weights from 'weights_best.h5'.

# %% [markdown]
# ## Inferimos

# %%
# %%writefile /nas/vruiz/cryoCARE/epfl1/predict_config__projected.json
# {
#     "path": "./model.tar.gz",
#     "even": ["epfl1_subset1_float.mrc"],
#     "odd": ["epfl1_subset1_float.mrc"],
#     "n_tiles": [1,1,1],
#     "output": "projected_denoised",
#     "overwrite": "True",
#     "gpu_id": [0, 1]
# }
# Out:
# Overwriting /nas/vruiz/cryoCARE/epfl1/predict_config__projected.json

# %%
# %%bash
# cd /nas/vruiz/cryoCARE/epfl1
# pwd
# source ~/envs/cryoCARE/bin/activate
# cryoCARE_predict.py --conf predict_config__projected.json || true
# Out:
# /nas/vruiz/cryoCARE/epfl1
# 2025-10-02 21:14:55.509995: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-02 21:15:00.769049: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2025-10-02 21:15:00.769760: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2025-10-02 21:15:00.794176: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 21:15:00.796218: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:c1:00.0 name: NVIDIA A30 computeCapability: 8.0
# coreClock: 1.44GHz coreCount: 56 deviceMemorySize: 23.60GiB deviceMemoryBandwidth: 869.04GiB/s
# 2025-10-02 21:15:00.796291: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 21:15:00.796492: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:41:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.73GiB deviceMemoryBandwidth: 836.37GiB/s
# 2025-10-02 21:15:00.796508: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-02 21:15:00.801336: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2025-10-02 21:15:00.801372: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2025-10-02 21:15:00.803708: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2025-10-02 21:15:00.805069: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2025-10-02 21:15:00.808799: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2025-10-02 21:15:00.810552: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2025-10-02 21:15:00.811990: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2025-10-02 21:15:00.812075: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 21:15:00.815012: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 21:15:00.815235: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 21:15:00.817179: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 21:15:00.817356: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2025-10-02 21:15:00.910614: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2025-10-02 21:15:01.180674: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 21:15:01.182179: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:c1:00.0 name: NVIDIA A30 computeCapability: 8.0
# coreClock: 1.44GHz coreCount: 56 deviceMemorySize: 23.60GiB deviceMemoryBandwidth: 869.04GiB/s
# 2025-10-02 21:15:01.182247: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 21:15:01.182421: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:41:00.0 name: Tesla V100-PCIE-32GB computeCapability: 7.0
# coreClock: 1.38GHz coreCount: 80 deviceMemorySize: 31.73GiB deviceMemoryBandwidth: 836.37GiB/s
# 2025-10-02 21:15:01.182449: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-02 21:15:01.182475: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2025-10-02 21:15:01.182485: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2025-10-02 21:15:01.182494: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2025-10-02 21:15:01.182511: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2025-10-02 21:15:01.182520: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2025-10-02 21:15:01.182529: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2025-10-02 21:15:01.182538: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2025-10-02 21:15:01.182589: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 21:15:01.183941: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 21:15:01.184142: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 21:15:01.185499: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 21:15:01.185675: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0, 1
# 2025-10-02 21:15:01.185709: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2025-10-02 21:15:02.009486: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2025-10-02 21:15:02.009525: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0 1
# 2025-10-02 21:15:02.009533: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N N
# 2025-10-02 21:15:02.009537: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 1:   N N
# 2025-10-02 21:15:02.009924: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 21:15:02.011585: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 21:15:02.011796: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 21:15:02.013175: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 21:15:02.014515: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 22349 MB memory) -> physical GPU (device: 0, name: NVIDIA A30, pci bus id: 0000:c1:00.0, compute capability: 8.0)
# 2025-10-02 21:15:02.014993: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 21:15:02.015205: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2025-10-02 21:15:02.015371: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:1 with 14390 MB memory) -> physical GPU (device: 1, name: Tesla V100-PCIE-32GB, pci bus id: 0000:41:00.0, compute capability: 7.0)
# 2025-10-02 21:15:03.256682: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2025-10-02 21:15:03.257049: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2595155000 Hz
# 2025-10-02 21:15:04.163585: W tensorflow/core/kernels/gpu_utils.cc:49] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# 2025-10-02 21:15:04.163722: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2025-10-02 21:15:06.204111: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2025-10-02 21:15:06.338233: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2025-10-02 21:15:09.590994: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2025-10-02 21:15:10.067678: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2025-10-02 21:15:20.068846: W tensorflow/core/common_runtime/bfc_allocator.cc:433] Allocator (GPU_0_bfc) ran out of memory trying to allocate 7.12GiB (rounded to 7650410496)requested by op model/down_level_0_no_1/Conv3D
# Current allocation summary follows.
# 2025-10-02 21:15:20.068901: I tensorflow/core/common_runtime/bfc_allocator.cc:972] BFCAllocator dump for GPU_0_bfc
# 2025-10-02 21:15:20.068932: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (256): 	Total Chunks: 34, Chunks in use: 34. 8.5KiB allocated for chunks. 8.5KiB in use in bin. 2.0KiB client-requested in use in bin.
# 2025-10-02 21:15:20.068945: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (512): 	Total Chunks: 1, Chunks in use: 1. 512B allocated for chunks. 512B in use in bin. 512B client-requested in use in bin.
# 2025-10-02 21:15:20.068958: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1024): 	Total Chunks: 3, Chunks in use: 2. 4.0KiB allocated for chunks. 3.0KiB in use in bin. 2.7KiB client-requested in use in bin.
# 2025-10-02 21:15:20.068970: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:15:20.068982: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:15:20.069009: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:15:20.069023: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16384): 	Total Chunks: 3, Chunks in use: 1. 81.5KiB allocated for chunks. 27.0KiB in use in bin. 27.0KiB client-requested in use in bin.
# 2025-10-02 21:15:20.069037: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (32768): 	Total Chunks: 3, Chunks in use: 3. 159.0KiB allocated for chunks. 159.0KiB in use in bin. 135.0KiB client-requested in use in bin.
# 2025-10-02 21:15:20.069050: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (65536): 	Total Chunks: 1, Chunks in use: 1. 77.8KiB allocated for chunks. 77.8KiB in use in bin. 54.0KiB client-requested in use in bin.
# 2025-10-02 21:15:20.069063: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (131072): 	Total Chunks: 3, Chunks in use: 3. 567.0KiB allocated for chunks. 567.0KiB in use in bin. 540.0KiB client-requested in use in bin.
# 2025-10-02 21:15:20.069076: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (262144): 	Total Chunks: 1, Chunks in use: 1. 320.0KiB allocated for chunks. 320.0KiB in use in bin. 216.0KiB client-requested in use in bin.
# 2025-10-02 21:15:20.069089: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (524288): 	Total Chunks: 4, Chunks in use: 4. 3.13MiB allocated for chunks. 3.13MiB in use in bin. 2.95MiB client-requested in use in bin.
# 2025-10-02 21:15:20.069100: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1048576): 	Total Chunks: 2, Chunks in use: 0. 2.68MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:15:20.069112: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:15:20.069123: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:15:20.069134: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:15:20.069145: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:15:20.069157: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:15:20.069168: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:15:20.069179: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:15:20.069192: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (268435456): 	Total Chunks: 5, Chunks in use: 3. 16.50GiB allocated for chunks. 14.75GiB in use in bin. 14.70GiB client-requested in use in bin.
# 2025-10-02 21:15:20.069204: I tensorflow/core/common_runtime/bfc_allocator.cc:995] Bin for 7.12GiB was 256.00MiB, Chunk State:
# 2025-10-02 21:15:20.069223: I tensorflow/core/common_runtime/bfc_allocator.cc:1001]   Size: 896.00MiB | Requested Size: 4B | in_use: 0 | bin_num: 20, prev:   Size: 7.12GiB | Requested Size: 7.12GiB | in_use: 1 | bin_num: -1
# 2025-10-02 21:15:20.069238: I tensorflow/core/common_runtime/bfc_allocator.cc:1001]   Size: 896.00MiB | Requested Size: 54.0KiB | in_use: 0 | bin_num: 20, prev:   Size: 7.12GiB | Requested Size: 7.12GiB | in_use: 1 | bin_num: -1
# 2025-10-02 21:15:20.069248: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 8589934592
# 2025-10-02 21:15:20.069262: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c04e0000000 of size 7650410496 next 12
# 2025-10-02 21:15:20.069273: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7c06a8000000 of size 939524096 next 18446744073709551615
# 2025-10-02 21:15:20.069283: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 8589934592
# 2025-10-02 21:15:20.069293: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c06e0000000 of size 7650410496 next 16
# 2025-10-02 21:15:20.069303: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7c08a8000000 of size 939524096 next 18446744073709551615
# 2025-10-02 21:15:20.069312: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 536870912
# 2025-10-02 21:15:20.069364: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c08e0000000 of size 536870912 next 18446744073709551615
# 2025-10-02 21:15:20.069376: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 4194304
# 2025-10-02 21:15:20.069386: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0a32000000 of size 884736 next 36
# 2025-10-02 21:15:20.069396: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0a320d8000 of size 884736 next 34
# 2025-10-02 21:15:20.069406: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0a321b0000 of size 884736 next 38
# 2025-10-02 21:15:20.069416: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7c0a32288000 of size 1540096 next 18446744073709551615
# 2025-10-02 21:15:20.069425: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 1048576
# 2025-10-02 21:15:20.069436: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00000 of size 1280 next 1
# 2025-10-02 21:15:20.069446: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00500 of size 256 next 5
# 2025-10-02 21:15:20.069456: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00600 of size 256 next 8
# 2025-10-02 21:15:20.069466: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00700 of size 256 next 10
# 2025-10-02 21:15:20.069475: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00800 of size 256 next 11
# 2025-10-02 21:15:20.069485: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00900 of size 256 next 9
# 2025-10-02 21:15:20.069495: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00a00 of size 256 next 14
# 2025-10-02 21:15:20.069505: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00b00 of size 256 next 2
# 2025-10-02 21:15:20.069515: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00c00 of size 256 next 3
# 2025-10-02 21:15:20.069524: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00d00 of size 256 next 4
# 2025-10-02 21:15:20.069534: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00e00 of size 256 next 17
# 2025-10-02 21:15:20.069544: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00f00 of size 256 next 19
# 2025-10-02 21:15:20.069553: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01000 of size 256 next 20
# 2025-10-02 21:15:20.069563: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01100 of size 256 next 18
# 2025-10-02 21:15:20.069573: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01200 of size 256 next 23
# 2025-10-02 21:15:20.069582: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01300 of size 256 next 24
# 2025-10-02 21:15:20.069592: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01400 of size 256 next 25
# 2025-10-02 21:15:20.069602: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01500 of size 256 next 6
# 2025-10-02 21:15:20.069611: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01600 of size 256 next 58
# 2025-10-02 21:15:20.069622: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01700 of size 512 next 31
# 2025-10-02 21:15:20.069631: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7c0b6ba01900 of size 1024 next 7
# 2025-10-02 21:15:20.069641: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01d00 of size 256 next 29
# 2025-10-02 21:15:20.069651: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01e00 of size 256 next 28
# 2025-10-02 21:15:20.069661: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01f00 of size 256 next 32
# 2025-10-02 21:15:20.069671: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02000 of size 256 next 33
# 2025-10-02 21:15:20.069682: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02100 of size 256 next 37
# 2025-10-02 21:15:20.069692: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02200 of size 256 next 30
# 2025-10-02 21:15:20.069701: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02300 of size 256 next 41
# 2025-10-02 21:15:20.069709: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02400 of size 256 next 46
# 2025-10-02 21:15:20.069718: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02500 of size 256 next 44
# 2025-10-02 21:15:20.069724: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02600 of size 256 next 26
# 2025-10-02 21:15:20.069729: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02700 of size 256 next 51
# 2025-10-02 21:15:20.069733: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02800 of size 256 next 49
# 2025-10-02 21:15:20.069737: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02900 of size 52224 next 13
# 2025-10-02 21:15:20.069742: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba0f500 of size 138240 next 15
# 2025-10-02 21:15:20.069746: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7c0b6ba31100 of size 28160 next 52
# 2025-10-02 21:15:20.069750: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba37f00 of size 256 next 53
# 2025-10-02 21:15:20.069754: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba38000 of size 256 next 54
# 2025-10-02 21:15:20.069758: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba38100 of size 256 next 55
# 2025-10-02 21:15:20.069762: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba38200 of size 256 next 56
# 2025-10-02 21:15:20.069766: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba38300 of size 1792 next 57
# 2025-10-02 21:15:20.069770: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba38a00 of size 79616 next 45
# 2025-10-02 21:15:20.069774: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba4c100 of size 27648 next 47
# 2025-10-02 21:15:20.069778: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7c0b6ba52d00 of size 27648 next 48
# 2025-10-02 21:15:20.069782: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba59900 of size 55296 next 22
# 2025-10-02 21:15:20.069786: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba67100 of size 626432 next 18446744073709551615
# 2025-10-02 21:15:20.069790: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 2097152
# 2025-10-02 21:15:20.069794: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6bc00000 of size 221184 next 39
# 2025-10-02 21:15:20.069798: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6bc36000 of size 221184 next 40
# 2025-10-02 21:15:20.069802: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6bc6c000 of size 55296 next 42
# 2025-10-02 21:15:20.069806: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7c0b6bc79800 of size 1271808 next 43
# 2025-10-02 21:15:20.069810: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6bdb0000 of size 327680 next 18446744073709551615
# 2025-10-02 21:15:20.069814: I tensorflow/core/common_runtime/bfc_allocator.cc:1033]      Summary of in-use Chunks by size:
# 2025-10-02 21:15:20.069820: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 34 Chunks of size 256 totalling 8.5KiB
# 2025-10-02 21:15:20.069824: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 512 totalling 512B
# 2025-10-02 21:15:20.069828: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 1280 totalling 1.2KiB
# 2025-10-02 21:15:20.069833: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 1792 totalling 1.8KiB
# 2025-10-02 21:15:20.069838: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 27648 totalling 27.0KiB
# 2025-10-02 21:15:20.069842: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 52224 totalling 51.0KiB
# 2025-10-02 21:15:20.069847: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 55296 totalling 108.0KiB
# 2025-10-02 21:15:20.069851: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 79616 totalling 77.8KiB
# 2025-10-02 21:15:20.069856: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 138240 totalling 135.0KiB
# 2025-10-02 21:15:20.069860: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 221184 totalling 432.0KiB
# 2025-10-02 21:15:20.069864: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 327680 totalling 320.0KiB
# 2025-10-02 21:15:20.069869: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 626432 totalling 611.8KiB
# 2025-10-02 21:15:20.069873: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 884736 totalling 2.53MiB
# 2025-10-02 21:15:20.069877: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 536870912 totalling 512.00MiB
# 2025-10-02 21:15:20.069882: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 7650410496 totalling 14.25GiB
# 2025-10-02 21:15:20.069886: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Sum Total of in-use chunks: 14.75GiB
# 2025-10-02 21:15:20.069890: I tensorflow/core/common_runtime/bfc_allocator.cc:1042] total_region_allocated_bytes_: 17724080128 memory_limit_: 23435456000 available bytes: 5711375872 curr_region_allocation_bytes_: 17179869184
# 2025-10-02 21:15:20.069898: I tensorflow/core/common_runtime/bfc_allocator.cc:1048] Stats:
# Limit:                     23435456000
# InUse:                     15842163200
# MaxInUse:                  15860711680
# NumAllocs:                         132
# MaxAllocSize:               7650410496
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-10-02 21:15:20.069905: W tensorflow/core/common_runtime/bfc_allocator.cc:441] ********************************************____********************************************____****
# 2025-10-02 21:15:20.069934: W tensorflow/core/framework/op_kernel.cc:1763] OP_REQUIRES failed at conv_ops_3d.cc:227 : Resource exhausted: OOM when allocating tensor with shape[1,16,152,768,1024] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 2025-10-02 21:16:01.967426: W tensorflow/core/common_runtime/bfc_allocator.cc:433] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.90GiB (rounded to 4183818240)requested by op model/up_level_0_no_0/Conv3D
# Current allocation summary follows.
# 2025-10-02 21:16:01.967487: I tensorflow/core/common_runtime/bfc_allocator.cc:972] BFCAllocator dump for GPU_0_bfc
# 2025-10-02 21:16:01.967508: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (256): 	Total Chunks: 35, Chunks in use: 35. 8.8KiB allocated for chunks. 8.8KiB in use in bin. 2.0KiB client-requested in use in bin.
# 2025-10-02 21:16:01.967522: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (512): 	Total Chunks: 2, Chunks in use: 1. 1.2KiB allocated for chunks. 512B in use in bin. 512B client-requested in use in bin.
# 2025-10-02 21:16:01.967535: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1024): 	Total Chunks: 2, Chunks in use: 2. 3.0KiB allocated for chunks. 3.0KiB in use in bin. 2.7KiB client-requested in use in bin.
# 2025-10-02 21:16:01.967547: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:16:01.967558: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:16:01.967569: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:16:01.967583: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16384): 	Total Chunks: 3, Chunks in use: 1. 81.5KiB allocated for chunks. 27.0KiB in use in bin. 27.0KiB client-requested in use in bin.
# 2025-10-02 21:16:01.967597: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (32768): 	Total Chunks: 4, Chunks in use: 4. 213.0KiB allocated for chunks. 213.0KiB in use in bin. 189.0KiB client-requested in use in bin.
# 2025-10-02 21:16:01.967612: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (65536): 	Total Chunks: 1, Chunks in use: 1. 77.8KiB allocated for chunks. 77.8KiB in use in bin. 54.0KiB client-requested in use in bin.
# 2025-10-02 21:16:01.967625: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (131072): 	Total Chunks: 3, Chunks in use: 3. 567.0KiB allocated for chunks. 567.0KiB in use in bin. 540.0KiB client-requested in use in bin.
# 2025-10-02 21:16:01.967638: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (262144): 	Total Chunks: 1, Chunks in use: 1. 320.0KiB allocated for chunks. 320.0KiB in use in bin. 216.0KiB client-requested in use in bin.
# 2025-10-02 21:16:01.967650: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (524288): 	Total Chunks: 4, Chunks in use: 4. 3.13MiB allocated for chunks. 3.13MiB in use in bin. 2.95MiB client-requested in use in bin.
# 2025-10-02 21:16:01.967662: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (1048576): 	Total Chunks: 2, Chunks in use: 0. 2.63MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:16:01.967673: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:16:01.967685: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:16:01.967696: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:16:01.967708: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:16:01.967717: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:16:01.967726: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-02 21:16:01.967737: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (134217728): 	Total Chunks: 3, Chunks in use: 1. 673.38MiB allocated for chunks. 249.38MiB in use in bin. 249.38MiB client-requested in use in bin.
# 2025-10-02 21:16:01.967748: I tensorflow/core/common_runtime/bfc_allocator.cc:979] Bin (268435456): 	Total Chunks: 5, Chunks in use: 3. 21.16GiB allocated for chunks. 19.48GiB in use in bin. 19.48GiB client-requested in use in bin.
# 2025-10-02 21:16:01.967758: I tensorflow/core/common_runtime/bfc_allocator.cc:995] Bin for 3.90GiB was 256.00MiB, Chunk State:
# 2025-10-02 21:16:01.967774: I tensorflow/core/common_runtime/bfc_allocator.cc:1001]   Size: 262.62MiB | Requested Size: 7.12MiB | in_use: 0 | bin_num: 20, prev:   Size: 249.38MiB | Requested Size: 249.38MiB | in_use: 1 | bin_num: -1
# 2025-10-02 21:16:01.967785: I tensorflow/core/common_runtime/bfc_allocator.cc:1001]   Size: 1.42GiB | Requested Size: 3.90GiB | in_use: 0 | bin_num: 20, prev:   Size: 3.90GiB | Requested Size: 3.90GiB | in_use: 1 | bin_num: -1
# 2025-10-02 21:16:01.967793: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 5711375872
# 2025-10-02 21:16:01.967805: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0212000000 of size 4183818240 next 60
# 2025-10-02 21:16:01.967814: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7c030b600000 of size 1527557632 next 18446744073709551615
# 2025-10-02 21:16:01.967822: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 8589934592
# 2025-10-02 21:16:01.967830: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c04e0000000 of size 8367636480 next 61
# 2025-10-02 21:16:01.967839: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7c06d2c00000 of size 222298112 next 18446744073709551615
# 2025-10-02 21:16:01.967846: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 8589934592
# 2025-10-02 21:16:01.967855: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c06e0000000 of size 8367636480 next 221
# 2025-10-02 21:16:01.967863: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7c08d2c00000 of size 222298112 next 18446744073709551615
# 2025-10-02 21:16:01.967871: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 536870912
# 2025-10-02 21:16:01.967879: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c08e0000000 of size 261488640 next 12
# 2025-10-02 21:16:01.967887: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7c08ef960000 of size 275382272 next 18446744073709551615
# 2025-10-02 21:16:01.967895: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 4194304
# 2025-10-02 21:16:01.967903: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0a32000000 of size 884736 next 36
# 2025-10-02 21:16:01.967920: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0a320d8000 of size 884736 next 34
# 2025-10-02 21:16:01.967928: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0a321b0000 of size 884736 next 38
# 2025-10-02 21:16:01.967936: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7c0a32288000 of size 1540096 next 18446744073709551615
# 2025-10-02 21:16:01.967944: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 1048576
# 2025-10-02 21:16:01.967954: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00000 of size 1280 next 1
# 2025-10-02 21:16:01.967962: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00500 of size 256 next 5
# 2025-10-02 21:16:01.967970: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00600 of size 256 next 8
# 2025-10-02 21:16:01.967978: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00700 of size 256 next 10
# 2025-10-02 21:16:01.967986: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00800 of size 256 next 11
# 2025-10-02 21:16:01.967994: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00900 of size 256 next 9
# 2025-10-02 21:16:01.968002: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00a00 of size 256 next 14
# 2025-10-02 21:16:01.968011: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00b00 of size 256 next 2
# 2025-10-02 21:16:01.968019: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00c00 of size 256 next 3
# 2025-10-02 21:16:01.968027: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00d00 of size 256 next 4
# 2025-10-02 21:16:01.968035: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00e00 of size 256 next 17
# 2025-10-02 21:16:01.968043: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba00f00 of size 256 next 19
# 2025-10-02 21:16:01.968051: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01000 of size 256 next 20
# 2025-10-02 21:16:01.968059: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01100 of size 256 next 18
# 2025-10-02 21:16:01.968067: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01200 of size 256 next 23
# 2025-10-02 21:16:01.968075: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01300 of size 256 next 24
# 2025-10-02 21:16:01.968083: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01400 of size 256 next 25
# 2025-10-02 21:16:01.968091: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01500 of size 256 next 6
# 2025-10-02 21:16:01.968099: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01600 of size 256 next 58
# 2025-10-02 21:16:01.968108: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01700 of size 512 next 31
# 2025-10-02 21:16:01.968116: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01900 of size 256 next 16
# 2025-10-02 21:16:01.968124: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7c0b6ba01a00 of size 768 next 7
# 2025-10-02 21:16:01.968132: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01d00 of size 256 next 29
# 2025-10-02 21:16:01.968140: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01e00 of size 256 next 28
# 2025-10-02 21:16:01.968148: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba01f00 of size 256 next 32
# 2025-10-02 21:16:01.968156: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02000 of size 256 next 33
# 2025-10-02 21:16:01.968164: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02100 of size 256 next 37
# 2025-10-02 21:16:01.968172: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02200 of size 256 next 30
# 2025-10-02 21:16:01.968181: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02300 of size 256 next 41
# 2025-10-02 21:16:01.968189: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02400 of size 256 next 46
# 2025-10-02 21:16:01.968197: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02500 of size 256 next 44
# 2025-10-02 21:16:01.968205: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02600 of size 256 next 26
# 2025-10-02 21:16:01.968213: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02700 of size 256 next 51
# 2025-10-02 21:16:01.968221: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02800 of size 256 next 49
# 2025-10-02 21:16:01.968230: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba02900 of size 52224 next 13
# 2025-10-02 21:16:01.968238: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba0f500 of size 138240 next 15
# 2025-10-02 21:16:01.968246: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7c0b6ba31100 of size 28160 next 52
# 2025-10-02 21:16:01.968254: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba37f00 of size 256 next 53
# 2025-10-02 21:16:01.968262: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba38000 of size 256 next 54
# 2025-10-02 21:16:01.968270: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba38100 of size 256 next 55
# 2025-10-02 21:16:01.968278: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba38200 of size 256 next 56
# 2025-10-02 21:16:01.968287: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba38300 of size 1792 next 57
# 2025-10-02 21:16:01.968295: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba38a00 of size 79616 next 45
# 2025-10-02 21:16:01.968304: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba4c100 of size 27648 next 47
# 2025-10-02 21:16:01.968312: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7c0b6ba52d00 of size 27648 next 48
# 2025-10-02 21:16:01.968351: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba59900 of size 55296 next 22
# 2025-10-02 21:16:01.968362: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6ba67100 of size 626432 next 18446744073709551615
# 2025-10-02 21:16:01.968370: I tensorflow/core/common_runtime/bfc_allocator.cc:1008] Next region of size 2097152
# 2025-10-02 21:16:01.968379: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6bc00000 of size 221184 next 39
# 2025-10-02 21:16:01.968387: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6bc36000 of size 221184 next 40
# 2025-10-02 21:16:01.968395: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6bc6c000 of size 55296 next 42
# 2025-10-02 21:16:01.968403: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6bc79800 of size 55296 next 445
# 2025-10-02 21:16:01.968412: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] Free  at 7c0b6bc87000 of size 1216512 next 43
# 2025-10-02 21:16:01.968420: I tensorflow/core/common_runtime/bfc_allocator.cc:1028] InUse at 7c0b6bdb0000 of size 327680 next 18446744073709551615
# 2025-10-02 21:16:01.968428: I tensorflow/core/common_runtime/bfc_allocator.cc:1033]      Summary of in-use Chunks by size:
# 2025-10-02 21:16:01.968439: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 35 Chunks of size 256 totalling 8.8KiB
# 2025-10-02 21:16:01.968448: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 512 totalling 512B
# 2025-10-02 21:16:01.968457: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 1280 totalling 1.2KiB
# 2025-10-02 21:16:01.968466: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 1792 totalling 1.8KiB
# 2025-10-02 21:16:01.968475: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 27648 totalling 27.0KiB
# 2025-10-02 21:16:01.968485: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 52224 totalling 51.0KiB
# 2025-10-02 21:16:01.968494: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 55296 totalling 162.0KiB
# 2025-10-02 21:16:01.968503: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 79616 totalling 77.8KiB
# 2025-10-02 21:16:01.968513: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 138240 totalling 135.0KiB
# 2025-10-02 21:16:01.968522: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 221184 totalling 432.0KiB
# 2025-10-02 21:16:01.968531: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 327680 totalling 320.0KiB
# 2025-10-02 21:16:01.968540: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 626432 totalling 611.8KiB
# 2025-10-02 21:16:01.968549: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 3 Chunks of size 884736 totalling 2.53MiB
# 2025-10-02 21:16:01.968558: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 261488640 totalling 249.38MiB
# 2025-10-02 21:16:01.968567: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 1 Chunks of size 4183818240 totalling 3.90GiB
# 2025-10-02 21:16:01.968576: I tensorflow/core/common_runtime/bfc_allocator.cc:1036] 2 Chunks of size 8367636480 totalling 15.59GiB
# 2025-10-02 21:16:01.968585: I tensorflow/core/common_runtime/bfc_allocator.cc:1040] Sum Total of in-use chunks: 19.73GiB
# 2025-10-02 21:16:01.968593: I tensorflow/core/common_runtime/bfc_allocator.cc:1042] total_region_allocated_bytes_: 23435456000 memory_limit_: 23435456000 available bytes: 0 curr_region_allocation_bytes_: 34359738368
# 2025-10-02 21:16:01.968608: I tensorflow/core/common_runtime/bfc_allocator.cc:1048] Stats:
# Limit:                     23435456000
# InUse:                     21185106688
# MaxInUse:                  21229250304
# NumAllocs:                        1574
# MaxAllocSize:               8367636480
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-10-02 21:16:01.968624: W tensorflow/core/common_runtime/bfc_allocator.cc:441] ******************______****************************************************************************
# 2025-10-02 21:16:01.968658: W tensorflow/core/framework/op_kernel.cc:1763] OP_REQUIRES failed at conv_ops_3d.cc:327 : Resource exhausted: OOM when allocating tensor with shape[1,16,152,768,560] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 2025-10-02 21:16:35.492687: I tensorflow/stream_executor/cuda/cuda_blas.cc:1838] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# Looking for GPU with ID: 0
# GPU 0 successfully found
# Looking for GPU with ID: 1
# GPU 1 successfully found
# Loading network weights from 'weights_best.h5'.
# (152, 768, 1024, 1)
# Out of memory, retrying with n_tiles = (1, 1, 2, 1)
# Out of memory, retrying with n_tiles = (1, 2, 2, 1)
# 100%|██████████| 4/4 [00:11<00:00,  2.93s/it]
# Traceback (most recent call last):
#   File "/home/jupyter-vruiz/envs/cryoCARE/bin/cryoCARE_predict.py", line 175, in <module>
#     main()
#   File "/home/jupyter-vruiz/envs/cryoCARE/bin/cryoCARE_predict.py", line 154, in main
#     denoise(config, mean, std, even=even, odd=odd, output_file=out_filename)
#   File "/home/jupyter-vruiz/envs/cryoCARE/bin/cryoCARE_predict.py", line 96, in denoise
#     new_label = np.concatenate((even.header[l][1:-1], np.array([
#   File "<__array_function__ internals>", line 5, in concatenate
# UnicodeDecodeError: 'ascii' codec can't decode byte 0x81 in position 3: ordinal not in range(128)

# %%
import mrcfile
import numpy as np
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt

# %%
def read_MRC(path_file):
    return mrcfile.read(mrc_file_path)

# %%
mrc_file_path = '/nas/vruiz/cryoCARE/epfl1/epfl1_subset1_float.mrc'
original_volume = read_MRC(mrc_file_path)

# %%
mrc_file_path = '/nas/vruiz/cryoCARE/epfl1/projected_denoised/epfl1_subset1_float.mrc'
denoised_volume = read_MRC(mrc_file_path)

# %%
# Choose a slice index in the middle of the volume for a good comparison
slice_idx = original_volume.shape[0] // 2

fig, axes = plt.subplots(1, 2, figsize=(20, 20))

# Plot the original slice z
im1 = axes[0].imshow(original_volume[slice_idx, :, :].T, cmap='gray', origin='lower')
axes[0].set_title(f'Original Slice Z={slice_idx}')
axes[0].grid(False)

# Plot the original slice z+1
im2 = axes[1].imshow(denoised_volume[slice_idx, :, :].T, cmap='gray', origin='lower')
axes[1].set_title(f'N2N Projected (Jose) Denoised Slice Z={slice_idx}')
axes[1].grid(False)

plt.tight_layout()
plt.show()

# %%
# %pip install "self_fourier_shell_correlation @ git+https://github.com/vicente-gonzalez-ruiz/self_fourier_shell_correlation"
# Out:
# Collecting self_fourier_shell_correlation@ git+https://github.com/vicente-gonzalez-ruiz/self_fourier_shell_correlation
#   Cloning https://github.com/vicente-gonzalez-ruiz/self_fourier_shell_correlation to /tmp/pip-install-c5e4e_q6/self-fourier-shell-correlation_16f4e3f561ba49c68ceb969b60a92b1d
#   Running command git clone --filter=blob:none --quiet https://github.com/vicente-gonzalez-ruiz/self_fourier_shell_correlation /tmp/pip-install-c5e4e_q6/self-fourier-shell-correlation_16f4e3f561ba49c68ceb969b60a92b1d
#   Resolved https://github.com/vicente-gonzalez-ruiz/self_fourier_shell_correlation to commit f785ed2aa883d5362036cc66d26498286c9a48ff
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip show self_fourier_shell_correlation
# Out:
# Name: self_fourier_shell_correlation
# Version: 0.0.1
# Summary: Self Fourier shell correlation (https://www.nature.com/articles/s42003-023-05724-y)
# Home-page: https://github.com/vicente-gonzalez-ruiz/self_fourier_shell_correlation
# Author:
# Author-email: "Eric J. Verbeke" <ev9102@princeton.edu>, Vicente González Ruiz <vicente.gonzalez.ruiz@gmail.com>
# License:
# Location: /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages
# Requires:
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install "shuffling @ git+https://github.com/vicente-gonzalez-ruiz/shuffling"
# Out:
# Collecting shuffling@ git+https://github.com/vicente-gonzalez-ruiz/shuffling
#   Cloning https://github.com/vicente-gonzalez-ruiz/shuffling to /tmp/pip-install-38zfblbs/shuffling_170034c155864fe6bc7b15468c58d997
#   Running command git clone --filter=blob:none --quiet https://github.com/vicente-gonzalez-ruiz/shuffling /tmp/pip-install-38zfblbs/shuffling_170034c155864fe6bc7b15468c58d997
#   Resolved https://github.com/vicente-gonzalez-ruiz/shuffling to commit 0710ed80bd40725b8fd116352c8e58a97f96528b
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.0 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from opencv-python) (1.19.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install "motion_estimation @ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation"
# Out:
# Collecting motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation
#   Cloning https://github.com/vicente-gonzalez-ruiz/motion_estimation to /tmp/pip-install-xp1w2039/motion-estimation_fa32d8eaa1e448eebdc5fb77bc9d37ae
#   Running command git clone --filter=blob:none --quiet https://github.com/vicente-gonzalez-ruiz/motion_estimation /tmp/pip-install-xp1w2039/motion-estimation_fa32d8eaa1e448eebdc5fb77bc9d37ae
#   Resolved https://github.com/vicente-gonzalez-ruiz/motion_estimation to commit 1f5e6bbf388db38c054f3ae38b4e82f074f7b493
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (1.19.5)
# Requirement already satisfied: opencv-python in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (4.12.0.88)
# Requirement already satisfied: matplotlib in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (3.6.3)
# Requirement already satisfied: contourpy>=1.0.1 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from matplotlib->motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from matplotlib->motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from matplotlib->motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from matplotlib->motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from matplotlib->motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from matplotlib->motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (10.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from matplotlib->motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from matplotlib->motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /nas/vruiz/envs/cryoCARE/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->motion_estimation@ git+https://github.com/vicente-gonzalez-ruiz/motion_estimation) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from self_fourier_shell_correlation import fsc_utils as fsc

# %%
import mrcfile

# %%
v1 = mrcfile.read("/nas/vruiz/cryoCARE/epfl1/epfl1_subset1_float.mrc")

# %%
v2 = mrcfile.read("/nas/vruiz/cryoCARE/epfl1/projected_volume.mrc")

# %%
spatial_freq, fsc_values = fsc.fourier_shell_correlation(v1, v2, shell_thickness=0.01)

# %%
fsc.plot_fsc(spatial_freq, fsc_values, "Spatial Frequency (1/voxel units)", "FSC", "FSC(even, odd)")
